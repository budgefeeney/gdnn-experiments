# %%
# !pip install nazca
# Out:
# ...
#      |████████████████████████████████| 901kB 6.0MB/s
# ...
#   Created wheel for nazca: filename=nazca-2.0.2-cp36-none-any.whl size=836741 sha256=7d3c52e151005e3bd5e6081b31ac50f9da6de8124ebd67113070c09f4ef5e5f1
#   Stored in directory: /root/.cache/pip/wheels/02/0f/4c/f250a5634d13e60c698155e0bf5f0ac2e28fd557326a77e71b
# Successfully built nazca
# ...

# %%
import nazca as nd

# %%
nd.a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-2a8ce5036b38> in <module>()
# ----> 1 nd.add_layer
#
# AttributeError: module 'nazca' has no attribute 'add_layer'

# %%
class Interconnects():
  name: str
  layer: int

  def __init__(self, name:str, layer: int):
    self.name = name
    self.layer = layer
    self.food = "tasty"
a
  def isfoodtasty(self):
    print(f"Food is {self.food}")

# %%
i = Interconnects(name="373737", layer=3)

# %%
dir(nazca)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__']

# %%
i.layer
# Out:
# 3

# %%
i.isfoodtasty()
# Out:
# Food is tasty
